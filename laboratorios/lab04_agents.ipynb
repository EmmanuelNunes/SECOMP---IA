# %% [markdown]
# # Laboratório 04: Construindo Agentes
#
# ## Objetivo
# Criar o primeiro agente autônomo e compreender seu funcionamento com ferramentas externas.

# %% [markdown]
# ## Arquitetura
# O fluxo padrão de um agente que toma decisões é:
#
# `Usuário` ---> `Agent` ---> `Tool` ---> `Resposta`

# %% [markdown]
# ## Exercício
# **Objetivo:** Criar um agente capaz de gerar o `README.md` de um repositório automaticamente.
#
# O **plano de execução** do agente deve ser:
# 1. Ler projeto
# 2. Identificar módulos
# 3. Criar documentação
# 4. Salvar arquivo

# %%
# 1. Defina as funções Python que serão as 'Tools' do agente:
def ler_projeto(diretorio):
    pass

def salvar_arquivo(conteudo, caminho):
    pass

# TODO: Inicializar o agente (ex: LangChain AgentExecutor) e passar as tools

# %% [markdown]
# ## Exercício Avançado
# Criar um **ResearchAgent** (Agente de Pesquisa).
#
# Ele deve ser capaz de:
# - consultar documentos;
# - resumir artigos;
# - gerar referências bibliográficas.

# %%
# Implemente aqui o ResearchAgent
