# %% [markdown]
# # Laboratório 01: Introdução aos LLMs
#
# ## Objetivo
# Compreender como um LLM processa texto e gera respostas.

# %% [markdown]
# ## Exercício 1
# Teste o seguinte prompt:

# %%
prompt_1 = "Explique o que é Inteligência Artificial em 100 palavras."

# Seu código para chamar o LLM aqui:
print(prompt_1)

# %% [markdown]
# ## Exercício 2
# Altere o seu prompt anterior e adicione a diretriz:
#
# > "Explique para um aluno do ensino médio."
#
# **Observe:**
# - tom;
# - profundidade;
# - complexidade.

# %%
prompt_2 = "Explique o que é Inteligência Artificial para um aluno do ensino médio."

# Seu código para chamar o LLM aqui:
print(prompt_2)

# %% [markdown]
# ## Exercício 3
# Compare os resultados entre um prompt vago e um prompt específico.

# %%
prompt_3_vago = "O que é RAG?"
prompt_3_especifico = "Explique RAG para um estudante de Ciência da Computação utilizando exemplos práticos."

# Seu código para chamar o LLM aqui:
print("Resposta Vaga:")
print("Resposta Específica:")
